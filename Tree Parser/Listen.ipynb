# %%
# To begin using librosa we need to import it, and other tools such as matplotlib and numpy
from __future__ import print_function # use the print() function from Python3
from operator import add
from pylab import *
import librosa             # The librosa library
import librosa.display     # librosa's display module (for plotting features)
import IPython.display     # IPython's display module (for in-line audio)
import matplotlib.pyplot as plt # matplotlib plotting functions
import matplotlib.style as ms   # plotting style
import numpy as np              # numpy numerical functions
ms.use('seaborn-muted')         # fancy plot designs
import soundfile as sf
from numpy import random
from scipy import signal
import matplotlib.pyplot as plt
from statistics import mean 
import librosa
import scipy.io.wavfile as wavf
import pandas as pd
from tree_lib import *

# %%
df = pd.read_csv("ratings.csv")

# %%
render_tups = render(df["expression"], 8000, 15)
renderings = render_tups[0]

# %%
IPython.display.Audio(renderings[499], rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
df2 = pd.read_csv("Partial_Data.csv")

# %%
df2.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-77c0659fc2a8> in <module>
# ----> 1 df2.describe()
#
# NameError: name 'df2' is not defined

# %%
df2.to_csv("spectral_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f41102df431e> in <module>
# ----> 1 df2.to_csv("spectral_data.csv")
#
# NameError: name 'df2' is not defined

# %%
corr = df2.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col0 {
#             background-color:  #b40426;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col1 {
#             background-color:  #779af7;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col3 {
#             background-color:  #7a9df8;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col4 {
#             background-color:  #92b4fe;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col5 {
#             background-color:  #4b64d5;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col1 {
#             background-color:  #b40426;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col2 {
#             background-color:  #5572df;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col3 {
#             background-color:  #c53334;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col4 {
#             background-color:  #3b4cc0;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col5 {
#             background-color:  #4055c8;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col0 {
#             background-color:  #5572df;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col1 {
#             background-color:  #a6c4fe;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col2 {
#             background-color:  #b40426;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col3 {
#             background-color:  #a1c0ff;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col4 {
#             background-color:  #ee8468;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col5 {
#             background-color:  #c0d4f5;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col0 {
#             background-color:  #4257c9;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col1 {
#             background-color:  #c53334;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col2 {
#             background-color:  #516ddb;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col3 {
#             background-color:  #b40426;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col4 {
#             background-color:  #3f53c6;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col5 {
#             background-color:  #3b4cc0;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col0 {
#             background-color:  #5673e0;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col1 {
#             background-color:  #3b4cc0;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col2 {
#             background-color:  #f6a283;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col3 {
#             background-color:  #3b4cc0;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col4 {
#             background-color:  #b40426;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col5 {
#             background-color:  #93b5fe;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row5_col0 {
#             background-color:  #5b7ae5;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row5_col1 {
#             background-color:  #8caffe;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row5_col2 {
#             background-color:  #b9d0f9;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row5_col3 {
#             background-color:  #82a6fb;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row5_col4 {
#             background-color:  #ccd9ed;
#         }    #T_04ca33ca_0470_11ea_8d21_f40f2430e613row5_col5 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_04ca33ca_0470_11ea_8d21_f40f2430e613" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >tempo</th>
#         <th class="col_heading level0 col1" >avg_cent</th>
#         <th class="col_heading level0 col2" >std_cent</th>
#         <th class="col_heading level0 col3" >avg_rolloff</th>
#         <th class="col_heading level0 col4" >std_rolloff</th>
#         <th class="col_heading level0 col5" >cont_rating</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_04ca33ca_0470_11ea_8d21_f40f2430e613level0_row0" class="row_heading level0 row0" >tempo</th>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col0" class="data row0 col0" >1</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col1" class="data row0 col1" >-0.0660366</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col2" class="data row0 col2" >0.0268444</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col3" class="data row0 col3" >-0.040319</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col4" class="data row0 col4" >0.0315801</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row0_col5" class="data row0 col5" >0.0486628</td>
#     </tr>    <tr>
#         <th id="T_04ca33ca_0470_11ea_8d21_f40f2430e613level0_row1" class="row_heading level0 row1" >avg_cent</th>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col0" class="data row1 col0" >-0.0660366</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col1" class="data row1 col1" >1</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col2" class="data row1 col2" >0.110479</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col3" class="data row1 col3" >0.937428</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col4" class="data row1 col4" >-0.316228</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row1_col5" class="data row1 col5" >0.012012</td>
#     </tr>    <tr>
#         <th id="T_04ca33ca_0470_11ea_8d21_f40f2430e613level0_row2" class="row_heading level0 row2" >std_cent</th>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col0" class="data row2 col0" >0.0268444</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col1" class="data row2 col1" >0.110479</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col2" class="data row2 col2" >1</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col3" class="data row2 col3" >0.101813</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col4" class="data row2 col4" >0.735518</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row2_col5" class="data row2 col5" >0.394314</td>
#     </tr>    <tr>
#         <th id="T_04ca33ca_0470_11ea_8d21_f40f2430e613level0_row3" class="row_heading level0 row3" >avg_rolloff</th>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col0" class="data row3 col0" >-0.040319</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col1" class="data row3 col1" >0.937428</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col2" class="data row3 col2" >0.101813</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col3" class="data row3 col3" >1</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col4" class="data row3 col4" >-0.295131</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row3_col5" class="data row3 col5" >-0.00792118</td>
#     </tr>    <tr>
#         <th id="T_04ca33ca_0470_11ea_8d21_f40f2430e613level0_row4" class="row_heading level0 row4" >std_rolloff</th>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col0" class="data row4 col0" >0.0315801</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col1" class="data row4 col1" >-0.316228</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col2" class="data row4 col2" >0.735518</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col3" class="data row4 col3" >-0.295131</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e613row4_col4" class="data row4 col4" >1</td>
#         <td id="T_04ca33ca_0470_11ea_8d21_f40f2430e6
